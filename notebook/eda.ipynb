# %% [markdown]
# ### EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
PATH = '../data/raw/heart_cleveland_upload.csv'
SEP = ','

# %%
df = pd.read_csv(PATH, sep=SEP)

# %%
df.shape
# Out:
# (297, 14)

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     69    1   0       160   234    1        2      131      0      0.1
# 1     69    0   0       140   239    0        0      151      0      1.8
# 2     66    0   0       150   226    0        0      114      0      2.6
# 3     65    1   0       138   282    1        2      174      0      1.4
# 4     64    1   0       110   211    0        2      144      1      1.8
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 292   40    1   3       152   223    0        0      181      0      0.0
# 293   39    1   3       118   219    0        0      140      0      1.2
# 294   35    1   3       120   198    0        0      130      1      1.6
# 295   35    0   3       138   183    0        0      182      0      1.4
# 296   35    1   3       126   282    0        2      156      1      0.0
#
#      slope  ca  thal  condition
# 0        1   1     0          0
# ...

# %%
df.groupby(by='condition').count()
# Out:
#            age  sex   cp  trestbps  chol  fbs  restecg  thalach  exang  \
# condition
# 0          160  160  160       160   160  160      160      160    160
# 1          137  137  137       137   137  137      137      137    137
#
#            oldpeak  slope   ca  thal
# condition
# 0              160    160  160   160
# 1              137    137  137   137

# %%
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_a3136_row0_col0, #T_a3136_row1_col1, #T_a3136_row2_col2, #T_a3136_row3_col3, #T_a3136_row4_col4, #T_a3136_row5_col5, #T_a3136_row6_col6, #T_a3136_row7_col7, #T_a3136_row8_col8, #T_a3136_row9_col9, #T_a3136_row10_col10, #T_a3136_row11_col11, #T_a3136_row12_col12, #T_a3136_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a3136_row0_col1 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_a3136_row0_col2, #T_a3136_row0_col3, #T_a3136_row0_col4 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_a3136_row0_col5, #T_a3136_row5_col4, #T_a3136_row10_col3 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_a3136_row0_col6, #T_a3136_row5_col2 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_a3136_row0_col7 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_a3136_row0_col8 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# ...

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  297.000000  297.000000  297.000000  297.000000  297.000000  297.000000
# mean    54.542088    0.676768    2.158249  131.693603  247.350168    0.144781
# std      9.049736    0.468500    0.964859   17.762806   51.997583    0.352474
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    2.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    2.000000  130.000000  243.000000    0.000000
# 75%     61.000000    1.000000    3.000000  140.000000  276.000000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  297.000000  297.000000  297.000000  297.000000  297.000000  297.000000
# mean     0.996633  149.599327    0.326599    1.055556    0.602694    0.676768
# ...

# %%
df.nunique()
# Out:
# age           41
# sex            2
# cp             4
# trestbps      50
# chol         152
# fbs            2
# restecg        3
# thalach       91
# exang          2
# oldpeak       40
# slope          3
# ca             4
# thal           3
# condition      2
# dtype: int64

# %%
df[['age', 'trestbps', 'chol', 'thalach', 'oldpeak']].hist()
# Out:
# array([[<AxesSubplot: title={'center': 'age'}>,
#         <AxesSubplot: title={'center': 'trestbps'}>],
#        [<AxesSubplot: title={'center': 'chol'}>,
#         <AxesSubplot: title={'center': 'thalach'}>],
#        [<AxesSubplot: title={'center': 'oldpeak'}>, <AxesSubplot: >]],
#       dtype=object)
